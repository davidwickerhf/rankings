# %%
import os
import pandas as pd
from tabulate import tabulate
import networkx as nx

# %%
def load_networks(path, max=100):
    """
    Load networks from a directory structure. Can handle both:
    1. Direct network files (nodes.json and edges.json in the input path)
    2. Networks in subdirectories
    
    Args:
        path: Root directory to search for networks or direct path to a network
        max: Maximum number of networks to load
    
    Returns:
        dict: Dictionary of networks with structure {network_name: {'nodes': df, 'edges': df}}
    """
    networks = {}
    loaded_count = 0
    
    # Verify root directory exists and print absolute path
    abs_root = os.path.abspath(path)
    print(f"Looking for networks in: {abs_root}")
    
    if not os.path.exists(abs_root):
        raise ValueError(f"Directory {abs_root} does not exist")
        
    def is_network_dir(dir_path):
        """Check if directory contains exactly nodes.json and edges.json"""
        try:
            contents = os.listdir(dir_path)
            return ('nodes.json' in contents and 'edges.json' in contents)
        except:
            return False
    
    def load_network(dir_path, network_name):
        """Load a single network from a directory"""
        print(f"\nChecking network: {network_name}")
        print(f"  Path: {dir_path}")
        
        nodes_file = os.path.join(dir_path, 'nodes.json')
        edges_file = os.path.join(dir_path, 'edges.json')
        
        try:
            # Load and validate data
            print("  Loading data files...")
            nodes_df = pd.read_json(nodes_file)
            edges_df = pd.read_json(edges_file)
            
            # Validate required columns
            required_node_cols = ['ecli', 'importance', 'doctypebranch']
            missing_cols = [col for col in required_node_cols if col not in nodes_df.columns]
            if missing_cols:
                print(f"  Warning: Missing columns in nodes.json: {missing_cols}")
                print(f"  Available columns: {nodes_df.columns.tolist()}")
                return False
            
            required_edge_cols = ['ecli', 'references']
            missing_edge_cols = [col for col in required_edge_cols if col not in edges_df.columns]
            if missing_edge_cols:
                print(f"  Warning: Missing columns in edges.json: {missing_edge_cols}")
                print(f"  Available columns: {edges_df.columns.tolist()}")
                return False
            
            networks[network_name] = {
                'nodes': nodes_df,
                'edges': edges_df
            }
            print(f"  Successfully loaded network with {len(nodes_df)} nodes and {len(edges_df)} edges")
            return True
            
        except Exception as e:
            print(f"  Error loading network: {str(e)}")
            return False
    
    def process_directory(current_path, parent_prefix=""):
        """Recursively process directories looking for networks"""
        nonlocal loaded_count
        if loaded_count >= max:
            return
            
        # First check if current directory is a network directory
        if is_network_dir(current_path):
            # Generate network name based on path
            rel_path = os.path.relpath(current_path, abs_root)
            network_name = rel_path.replace(os.sep, '-')
            if network_name == '.':  # Handle case where path is direct to network
                network_name = os.path.basename(current_path)
            
            if load_network(current_path, network_name):
                loaded_count += 1
            return
        
        # If not a network directory, search subdirectories
        try:
            for item in os.listdir(current_path):
                if loaded_count >= max:
                    break
                    
                item_path = os.path.join(current_path, item)
                if not os.path.isdir(item_path):
                    continue
                    
                process_directory(item_path)
        except Exception as e:
            print(f"Error accessing directory {current_path}: {str(e)}")
    
    # Start processing from root directory
    process_directory(abs_root)
    print(f"\nSuccessfully loaded {len(networks)} networks")
    return networks

# %%
def categorise_total_branch_numerically(branches: pd.Series) -> pd.Series:
    """
    Convert branch categorisation from strings into numbers.
    
    :param branches: The column containing branch data, categorized with strings.
    :return: A pandas Series with numerical categorization.
    """
    mapping = {
        "GRANDCHAMBER": 1,
        "CHAMBER": 2,
        "COMMITTEE": 3,
    }
    
    # Convert to uppercase to ensure consistent matching
    branches = branches.str.upper()
    
    # Print any values that don't match our mapping
    unmapped = set(branches.unique()) - set(mapping.keys())
    if unmapped:
        print(f"Warning: Found unmapped values: {unmapped}")
    
    return branches.map(mapping)

# %%
def analyze_network_stats(nodes_df, edges_df):
    """Calculate comprehensive statistics for a single network"""
    # Extract year from ECLI (format: ECLI:CE:ECHR:1998:0122JUD002620995)
    nodes_df['year'] = nodes_df['ecli'].str.extract(r':(\d{4}):')
    nodes_df['year'] = pd.to_numeric(nodes_df['year'], errors='coerce')
    
    # Convert doctypebranch to numeric if it exists
    if 'doctypebranch' in nodes_df.columns:
        nodes_df['doctypebranch'] = categorise_total_branch_numerically(nodes_df['doctypebranch'])
        # Remove rows with Nan doctypebranch
        nodes_df = nodes_df.dropna(subset=['doctypebranch'])

    # Convert importance to numeric
    nodes_df['importance'] = pd.to_numeric(nodes_df['importance'], errors='coerce')
    
    # Drop rows with missing ecli
    nodes_df = nodes_df.dropna(subset=['ecli'])
    
    # Create graph
    G = nx.DiGraph()
    
    # Add nodes with attributes
    valid_nodes = set(nodes_df['ecli'].values)
    for idx, row in nodes_df.iterrows():
        node_attrs = {
            'importance': row['importance'],
            'doctypebranch': row['doctypebranch'] if 'doctypebranch' in nodes_df.columns else None,
            'year': row['year']
        }
        G.add_node(row['ecli'], **node_attrs)
    
    # Add edges between existing nodes
    edge_count = 0
    for idx, row in edges_df.iterrows():
        source = row['ecli']
        targets = row['references']
        if source in valid_nodes:
            for target in targets:
                if target and target in valid_nodes:
                    G.add_edge(source, target)
                    edge_count += 1
    
    # Remove self-loops
    G.remove_edges_from(nx.selfloop_edges(G))
    
    # Basic network stats
    total_initial_nodes = len(nodes_df)
    total_valid_nodes = len(valid_nodes)
    total_edges = edge_count
    density = nx.density(G)
    
    # Connected nodes analysis
    connected_nodes = sum(1 for node in G.nodes() if G.degree(node) > 0)
    non_connected = total_valid_nodes - connected_nodes

    # Get connected components
    components = []
    for comp in nx.weakly_connected_components(G):
        if len(comp) >= 2:  # Only include components with 2+ nodes
            components.append(comp)

    num_components = len(components)
    biggest_component_size = len(max(components, key=len)) if components else 0
    
    # Class distributions
    doctypebranch_dist = nodes_df['doctypebranch'].value_counts().to_dict() if 'doctypebranch' in nodes_df.columns else {}
    importance_dist = nodes_df['importance'].value_counts().to_dict()

    
    # Split importance distributions by year
    pre_1998 = nodes_df[pd.to_datetime(nodes_df['judgementdate'].str.split(' ').str[0], format='%d/%m/%Y') < pd.to_datetime('01/11/1998', format='%d/%m/%Y')]
    post_1998 = nodes_df[pd.to_datetime(nodes_df['judgementdate'].str.split(' ').str[0], format='%d/%m/%Y') >= pd.to_datetime('01/11/1998', format='%d/%m/%Y')]
    importance_dist_pre_1998 = pre_1998['importance'].value_counts().to_dict()
    importance_dist_post_1998 = post_1998['importance'].value_counts().to_dict()
    
    return {
        'total_initial_nodes': total_initial_nodes,
        'total_valid_nodes': total_valid_nodes,
        'nodes_removed': total_initial_nodes - total_valid_nodes,
        'total_edges': total_edges,
        'connected_nodes': connected_nodes,
        'non_connected_nodes': non_connected,
        'num_components': num_components,
        'biggest_component_size': biggest_component_size,
        'density': density,
        'doctypebranch_dist': doctypebranch_dist,
        'importance_dist': importance_dist,
        'importance_dist_pre_1998': importance_dist_pre_1998,
        'importance_dist_post_1998': importance_dist_post_1998
    }

# %%
def create_network_summary():
    # Load all networks from different directories
    network_dirs = [
        'networks/merged-article-edges/full-balanced-importance',
        'networks/merged-article-edges/full-unbalanced',
        'networks/merged-article-edges/full-balanced-doctypebranch',
        'networks/merged-article-edges/split-balanced-importance',
        'networks/merged-article-edges/split-balanced-doctypebranch',
        'networks/merged-article-edges/split-unbalanced'
    ]
    
    networks = {}
    for dir_path in network_dirs:
        loaded_networks = load_networks(dir_path)
        # Prefix each network name with the directory name
        dir_name = dir_path.split('/')[-1]
        prefixed_networks = {
            f"{dir_name}-{network_name}": network_data
            for network_name, network_data in loaded_networks.items()
        }
        networks.update(prefixed_networks)
    
    # Analyze each network
    results = []
    for network_name, data in networks.items():
        stats = analyze_network_stats(data['nodes'], data['edges'])
        
        # Format class distributions for display
        doctypebranch_str = ', '.join([f"{k}: {v}" for k, v in stats['doctypebranch_dist'].items()])
        importance_str = ', '.join([f"{k}: {v}" for k, v in stats['importance_dist'].items()])
        importance_pre_1998_str = ', '.join([f"{k}: {v}" for k, v in stats['importance_dist_pre_1998'].items()])
        importance_post_1998_str = ', '.join([f"{k}: {v}" for k, v in stats['importance_dist_post_1998'].items()])
        
        results.append([
            network_name,
            stats['total_initial_nodes'],
            stats['total_valid_nodes'],
            stats['nodes_removed'],
            stats['total_edges'],
            stats['connected_nodes'],
            stats['non_connected_nodes'],
            stats['num_components'],
            stats['biggest_component_size'],
            f"{stats['density']:.8f}",
            doctypebranch_str,
            importance_str,
            importance_pre_1998_str,
            importance_post_1998_str
        ])

    # Create and display table
    headers = [
        'Network', 
        'Initial Nodes',
        'Valid Nodes',
        'Removed Nodes',
        'Total Edges', 
        'Connected Nodes',
        'Non-Connected Nodes',
        'Connected Components',
        'Biggest Component Size', 
        'Density',
        'Doctypebranch Distribution',
        'Importance Distribution',
        'Importance Pre-1998',
        'Importance Post-1998'
    ]
    
    # Sort results by valid nodes
    results.sort(key=lambda x: x[2], reverse=True)
    
    # Display table
    print(tabulate(results, headers=headers, tablefmt='grid'))
    
    # Save to CSV for further analysis
    df = pd.DataFrame(results, columns=headers)
    df.to_csv('network_statistics_updated.csv', index=False)

# %%
create_network_summary()
# Out:
# Looking for networks in: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/full-balanced-importance
#
# Checking network: full-balanced-importance
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/full-balanced-importance
#   Loading data files...
#   Successfully loaded network with 6450 nodes and 6450 edges
#
# Successfully loaded 1 networks
# Looking for networks in: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/full-unbalanced
#
# Checking network: full-unbalanced
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/full-unbalanced
#   Loading data files...
#   Successfully loaded network with 27801 nodes and 27801 edges
#
# Successfully loaded 1 networks
# Looking for networks in: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/full-balanced-doctypebranch
#
# Checking network: full-balanced-doctypebranch
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/full-balanced-doctypebranch
#   Loading data files...
#   Successfully loaded network with 1542 nodes and 1542 edges
#
# Successfully loaded 1 networks
# Looking for networks in: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance
#
# Checking network: article_10
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_10
#   Loading data files...
#   Successfully loaded network with 603 nodes and 603 edges
#
# Checking network: article_18
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_18
#   Loading data files...
#   Successfully loaded network with 62 nodes and 62 edges
#
# Checking network: article_11
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_11
#   Loading data files...
#   Successfully loaded network with 213 nodes and 213 edges
#
# Checking network: article_29
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_29
#   Loading data files...
#   Successfully loaded network with 557 nodes and 557 edges
#
# Checking network: article_34
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_34
#   Loading data files...
#   Successfully loaded network with 531 nodes and 531 edges
#
# Checking network: article_P4
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_P4
#   Loading data files...
#   Successfully loaded network with 80 nodes and 80 edges
#
# Checking network: article_35
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_35
#   Loading data files...
#   Successfully loaded network with 1585 nodes and 1585 edges
#
# Checking network: article_3
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_3
#   Loading data files...
#   Successfully loaded network with 1082 nodes and 1082 edges
#
# Checking network: article_5
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_5
#   Loading data files...
#   Successfully loaded network with 981 nodes and 981 edges
#
# Checking network: article_2
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_2
#   Loading data files...
#   Successfully loaded network with 427 nodes and 427 edges
#
# Checking network: article_13
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_13
#   Loading data files...
#   Successfully loaded network with 948 nodes and 948 edges
#
# Checking network: article_14
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_14
#   Loading data files...
#   Successfully loaded network with 528 nodes and 528 edges
#
# Checking network: article_46
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_46
#   Loading data files...
#   Successfully loaded network with 204 nodes and 204 edges
#
# Checking network: article_41
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_41
#   Loading data files...
#   Successfully loaded network with 3595 nodes and 3595 edges
#
# Checking network: article_37
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_37
#   Loading data files...
#   Successfully loaded network with 229 nodes and 229 edges
#
# Checking network: article_39
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_39
#   Loading data files...
#   Successfully loaded network with 106 nodes and 106 edges
#
# Checking network: article_P1
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_P1
#   Loading data files...
#   Successfully loaded network with 1021 nodes and 1021 edges
#
# Checking network: article_38
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_38
#   Loading data files...
#   Successfully loaded network with 114 nodes and 114 edges
#
# Checking network: article_P7
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_P7
#   Loading data files...
#   Successfully loaded network with 85 nodes and 85 edges
#
# Checking network: article_9
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_9
#   Loading data files...
#   Successfully loaded network with 125 nodes and 125 edges
#
# Checking network: article_7
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_7
#   Loading data files...
#   Successfully loaded network with 92 nodes and 92 edges
#
# Checking network: article_1
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_1
#   Loading data files...
#   Successfully loaded network with 66 nodes and 66 edges
#
# Checking network: article_6
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_6
#   Loading data files...
#   Successfully loaded network with 2987 nodes and 2987 edges
#
# Checking network: article_8
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-importance/article_8
#   Loading data files...
#   Successfully loaded network with 1126 nodes and 1126 edges
#
# Successfully loaded 24 networks
# Looking for networks in: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch
#
# Checking network: article_10
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_10
#   Loading data files...
#   Successfully loaded network with 142 nodes and 142 edges
#
# Checking network: article_11
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_11
#   Loading data files...
#   Successfully loaded network with 66 nodes and 66 edges
#
# Checking network: article_29
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_29
#   Loading data files...
#   Successfully loaded network with 74 nodes and 74 edges
#
# Checking network: article_34
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_34
#   Loading data files...
#   Successfully loaded network with 104 nodes and 104 edges
#
# Checking network: article_35
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_35
#   Loading data files...
#   Successfully loaded network with 268 nodes and 268 edges
#
# Checking network: article_3
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_3
#   Loading data files...
#   Successfully loaded network with 272 nodes and 272 edges
#
# Checking network: article_5
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_5
#   Loading data files...
#   Successfully loaded network with 261 nodes and 261 edges
#
# Checking network: article_2
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_2
#   Loading data files...
#   Successfully loaded network with 87 nodes and 87 edges
#
# Checking network: article_13
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_13
#   Loading data files...
#   Successfully loaded network with 229 nodes and 229 edges
#
# Checking network: article_14
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_14
#   Loading data files...
#   Successfully loaded network with 105 nodes and 105 edges
#
# Checking network: article_46
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_46
#   Loading data files...
#   Successfully loaded network with 51 nodes and 51 edges
#
# Checking network: article_41
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_41
#   Loading data files...
#   Successfully loaded network with 544 nodes and 544 edges
#
# Checking network: article_37
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_37
#   Loading data files...
#   Successfully loaded network with 78 nodes and 78 edges
#
# Checking network: article_P1
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_P1
#   Loading data files...
#   Successfully loaded network with 286 nodes and 286 edges
#
# Checking network: article_6
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_6
#   Loading data files...
#   Successfully loaded network with 730 nodes and 730 edges
#
# Checking network: article_8
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-balanced-doctypebranch/article_8
#   Loading data files...
#   Successfully loaded network with 230 nodes and 230 edges
#
# Successfully loaded 16 networks
# Looking for networks in: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced
#
# Checking network: article_17
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_17
#   Loading data files...
#   Successfully loaded network with 67 nodes and 67 edges
#
# Checking network: article_10
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_10
#   Loading data files...
#   Successfully loaded network with 1691 nodes and 1691 edges
#
# Checking network: article_18
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_18
#   Loading data files...
#   Successfully loaded network with 118 nodes and 118 edges
#
# Checking network: article_11
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_11
#   Loading data files...
#   Successfully loaded network with 854 nodes and 854 edges
#
# Checking network: article_29
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_29
#   Loading data files...
#   Successfully loaded network with 2521 nodes and 2521 edges
#
# Checking network: article_34
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_34
#   Loading data files...
#   Successfully loaded network with 1181 nodes and 1181 edges
#
# Checking network: article_P4
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_P4
#   Loading data files...
#   Successfully loaded network with 199 nodes and 199 edges
#
# Checking network: article_35
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_35
#   Loading data files...
#   Successfully loaded network with 3632 nodes and 3632 edges
#
# Checking network: article_3
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_3
#   Loading data files...
#   Successfully loaded network with 4606 nodes and 4606 edges
#
# Checking network: article_4
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_4
#   Loading data files...
#   Successfully loaded network with 56 nodes and 56 edges
#
# Checking network: article_5
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_5
#   Loading data files...
#   Successfully loaded network with 4302 nodes and 4302 edges
#
# Checking network: article_2
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_2
#   Loading data files...
#   Successfully loaded network with 1388 nodes and 1388 edges
#
# Checking network: article_13
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_13
#   Loading data files...
#   Successfully loaded network with 3990 nodes and 3990 edges
#
# Checking network: article_14
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_14
#   Loading data files...
#   Successfully loaded network with 1030 nodes and 1030 edges
#
# Checking network: article_46
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_46
#   Loading data files...
#   Successfully loaded network with 368 nodes and 368 edges
#
# Checking network: article_41
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_41
#   Loading data files...
#   Successfully loaded network with 10100 nodes and 10100 edges
#
# Checking network: article_37
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_37
#   Loading data files...
#   Successfully loaded network with 1254 nodes and 1254 edges
#
# Checking network: article_39
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_39
#   Loading data files...
#   Successfully loaded network with 852 nodes and 852 edges
#
# Checking network: article_P1
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_P1
#   Loading data files...
#   Successfully loaded network with 4746 nodes and 4746 edges
#
# Checking network: article_38
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_38
#   Loading data files...
#   Successfully loaded network with 594 nodes and 594 edges
#
# Checking network: article_P7
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_P7
#   Loading data files...
#   Successfully loaded network with 380 nodes and 380 edges
#
# Checking network: article_9
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_9
#   Loading data files...
#   Successfully loaded network with 243 nodes and 243 edges
#
# Checking network: article_7
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_7
#   Loading data files...
#   Successfully loaded network with 170 nodes and 170 edges
#
# Checking network: article_1
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_1
#   Loading data files...
#   Successfully loaded network with 102 nodes and 102 edges
#
# Checking network: article_6
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_6
#   Loading data files...
#   Successfully loaded network with 14811 nodes and 14811 edges
#
# Checking network: article_8
#   Path: /Users/davidwickerhf/Projects/work/maastrichtuniversity/rankings/networks/merged-article-edges/split-unbalanced/article_8
#   Loading data files...
#   Successfully loaded network with 3046 nodes and 3046 edges
#
# Successfully loaded 26 networks
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | Network                                                 |   Initial Nodes |   Valid Nodes |   Removed Nodes |   Total Edges |   Connected Nodes |   Non-Connected Nodes |   Connected Components |   Biggest Component Size |    Density | Doctypebranch Distribution   | Importance Distribution    | Importance Pre-1998    | Importance Post-1998       |
# +=========================================================+=================+===============+=================+===============+===================+=======================+========================+==========================+============+==============================+============================+========================+============================+
# | full-unbalanced-full-unbalanced                         |           27801 |         27801 |               0 |        232002 |             23306 |                  4495 |                     25 |                    23252 | 0.00030018 | 2: 20717, 3: 6570, 1: 514    | 3: 19895, 2: 5756, 1: 2150 | 1: 420, 2: 238, 3: 179 | 3: 19716, 2: 5518, 1: 1730 |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-unbalanced-article_6                              |           14811 |         14811 |               0 |         68812 |             11859 |                  2952 |                      6 |                    11847 | 0.00031371 | 2: 11282, 3: 3326, 1: 203    | 3: 11602, 2: 2359, 1: 850  | 1: 192, 2: 169, 3: 152 | 3: 11450, 2: 2190, 1: 658  |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-unbalanced-article_41                             |           10100 |         10100 |               0 |         75751 |              9058 |                  1042 |                     13 |                     9030 | 0.00074266 | 2: 9721, 1: 303, 3: 76       | 2: 4318, 3: 4271, 1: 1511  | 1: 258, 2: 150, 3: 86  | 3: 4185, 2: 4168, 1: 1253  |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
#

# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-importance-article_7                     |              92 |            92 |               0 |           328 |                77 |                    15 |                      1 |                       77 | 0.0391782  | 2: 68, 1: 24                 | 1: 55, 2: 32, 3: 5         | 1: 10, 2: 1            | 1: 45, 2: 31, 3: 5         |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-doctypebranch-article_2                  |              87 |            87 |               0 |           302 |                76 |                    11 |                      1 |                       76 | 0.0403635  | 1: 49, 2: 20, 3: 18          | 1: 49, 3: 32, 2: 6         | 1: 4                   | 1: 45, 3: 32, 2: 6         |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-importance-article_P7                    |              85 |            85 |               0 |           114 |                57 |                    28 |                      2 |                       55 | 0.0159664  | 2: 56, 3: 18, 1: 11          | 1: 36, 3: 26, 2: 23        | 1: 2, 2: 1             | 1: 34, 3: 26, 2: 22        |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-importance-article_P4                    |              80 |            80 |               0 |           211 |                68 |                    12 |                      2 |                       66 | 0.0333861  | 2: 64, 1: 13, 3: 3           | 1: 46, 2: 25, 3: 9         | 1: 6, 2: 1             | 1: 40, 2: 24, 3: 9         |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-doctypebranch-article_37                 |              78 |            78 |               0 |            57 |                34 |                    44 |                      2 |                       32 | 0.00949051 | 1: 40, 2: 30, 3: 8           | 3: 35, 1: 33, 2: 10        |                        | 3: 35, 1: 33, 2: 10        |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-doctypebranch-article_29                 |              74 |            74 |               0 |             3 |                 5 |                    69 |                      2 |                        3 | 0.00055535 | 2: 66, 1: 8                  | 3: 49, 2: 14, 1: 11        |                        | 3: 49, 2: 14, 1: 11        |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-unbalanced-article_17                             |              67 |            67 |               0 |            69 |                43 |                    24 |                      4 |                       28 | 0.0156038  | 2: 62, 1: 4, 3: 1            | 3: 23, 1: 22, 2: 22        | 1: 6, 2: 1             | 3: 23, 2: 21, 1: 16        |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-importance-article_1                     |              66 |            66 |               0 |           238 |                60 |                     6 |                      2 |                       58 | 0.0554779  | 2: 36, 1: 30                 | 1: 52, 2: 14               | 1: 7                   | 1: 45, 2: 14               |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-doctypebranch-article_11                 |              66 |            66 |               0 |            91 |                52 |                    14 |                      1 |                       52 | 0.0212121  | 3: 31, 1: 24, 2: 11          | 3: 35, 1: 23, 2: 8         | 1: 4                   | 3: 35, 1: 19, 2: 8         |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-importance-article_18                    |              62 |            62 |               0 |           189 |                48 |                    14 |                      1 |                       48 | 0.0499736  | 2: 48, 1: 14                 | 1: 40, 2: 20, 3: 2         | 1: 14, 2: 2            | 1: 26, 2: 18, 3: 2         |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-unbalanced-article_4                              |              56 |            56 |               0 |           132 |                35 |                    21 |                      2 |                       28 | 0.0428571  | 2: 52, 1: 4                  | 1: 22, 3: 21, 2: 13        | 1: 4                   | 3: 21, 1: 18, 2: 13        |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
# | split-balanced-doctypebranch-article_46                 |              51 |            51 |               0 |           233 |                44 |                     7 |                      1 |                       44 | 0.0913725  | 1: 44, 2: 7                  | 1: 47, 2: 4                | 1: 4                   | 1: 43, 2: 4                |
# +---------------------------------------------------------+-----------------+---------------+-----------------+---------------+-------------------+-----------------------+------------------------+--------------------------+------------+------------------------------+----------------------------+------------------------+----------------------------+
